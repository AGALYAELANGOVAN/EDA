# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("diabetes_prediction_dataset.csv")
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.shape
# Out:
# (100000, 9)

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB

# %%
df["gender"].unique(),df["smoking_history"].unique()
# Out:
# (array(['Female', 'Male', 'Other'], dtype=object),
#  array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#        dtype=object))

# %%
df.dtypes
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
sns.stripplot(x=df.diabetes,y=df.bmi,data=df,hue=df.gender)
# Out:
# <Axes: xlabel='diabetes', ylabel='bmi'>

# %%
sns.stripplot(x=df.diabetes,y=df.HbA1c_level,data=df,hue=df.gender)
# Out:
# <Axes: xlabel='diabetes', ylabel='HbA1c_level'>

# %%
sns.stripplot(x=df.diabetes,y=df.blood_glucose_level,data=df,hue=df.gender)
# Out:
# <Axes: xlabel='diabetes', ylabel='blood_glucose_level'>

# %%
#BMI
Body mass index (BMI) is a measurement that uses a person's height and weight to categorize them as underweight, normal weight, overweight, or obese.
#HbA1c
A hemoglobin A1C (HbA1c) test measures the average amount of glucose (sugar) in your blood over the past two to three months.
#BLOOD GLUOSE LEVEL
Blood glucose level, also known as blood sugar, is the amount of glucose in the blood. Glucose is a sugar that comes from food and is the body's main source of energy
# Out:
#   Cell In[13], line 2
#     Body mass index (BMI) is a measurement that uses a person's height and weight to categorize them as underweight, normal weight, overweight, or obese.
#                                                              ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(3854)

# %%
df=df.drop_duplicates()
df                          #to emove duplicates
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df.drop(df[(df['gender'] == "Other")].index)
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
df["gender"].unique()
# Out:
# array(['Female', 'Male', 'Other'], dtype=object)

# %%
df["smoking_history"].unique()
# Out:
# array(['never', 'No Info', 'current', 'former', 'ever', 'not current'],
#       dtype=object)

# %%
df['smoking_history'] = df['smoking_history'].replace('not current', 'former')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5808\1366871577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['smoking_history'] = df['smoking_history'].replace('not current', 'former')
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# ...

# %% [markdown]
# **LABEL ENCODING**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
gender=LabelEncoder()
smoker=LabelEncoder()
df["gender"]=gender.fit_transform(df.gender)
df["smoking_history"]=smoker.fit_transform(df.smoking_history)
df.head(5)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5808\2149077315.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["gender"]=gender.fit_transform(df.gender)
# C:\Users\HP\AppData\Local\Temp\ipykernel_5808\2149077315.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["smoking_history"]=smoker.fit_transform(df.smoking_history)
#    gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0       0  80.0             0              1                4  25.19
# ...

# %%
x=df[["gender","age","hypertension","heart_disease","smoking_history","bmi","HbA1c_level","blood_glucose_level"]]
y=df[["diabetes"]]
x.head(5),y.head(5)
# Out:
# (   gender   age  hypertension  heart_disease  smoking_history    bmi  \
#  0       0  80.0             0              1                4  25.19
#  1       0  54.0             0              0                0  27.32
#  2       1  28.0             0              0                4  27.32
#  3       0  36.0             0              0                1  23.45
#  4       1  76.0             1              1                1  20.14
#
#     HbA1c_level  blood_glucose_level
#  0          6.6                  140
#  1          6.6                   80
#  2          5.7                  158
#  3          5.0                  155
#  4          4.8                  155  ,
#     diabetes
#  0         0
#  1         0
#  2         0
#  3         0
#  4         0)

# %% [markdown]
# **SPILITING INTO TRAINING AND TESTING**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30, random_state=70)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((67302, 8), (28844, 8), (67302, 1), (28844, 1))

# %% [markdown]
# **TRAINING THE MODEL USING LOGISTIC REGRESSION**

# %%
def sigmoid(x):                  #ccreating logistic function
    return 1/(1+np.exp(-x))

# %%
sigmoid(-100000000000)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_5808\2009466116.py:2: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-x))
# np.float64(0.0)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_logit=LogisticRegression(max_iter=500)

# %%
model_logit.fit(X_train,y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=500)

# %% [markdown]
# **TESTING THE DATA**

# %%
y_pred=model_logit.predict(X_test)

# %%
model_logit.coef_*100
# Out:
# array([[ 22.54656838,   4.55706786,  76.76578598,  80.61892018,
#           9.88331442,   8.59163282, 233.86730053,   3.37872094]])

# %% [markdown]
# **FOR FINDING ACCURACY SCORE**

# %%
from sklearn.metrics import accuracy_score

accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.9598530023575094

# %% [markdown]
# **SGD CLASSIFIER**

# %%
from sklearn.linear_model import SGDClassifier  #STOCHASTIC GRADIENT DESCENT

# %%
model_LR1=SGDClassifier()

# %%
model_LR1.fit(X_train,y_train)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SGDClassifier()

# %%
y_pred1=model_LR1.predict(X_test)
y_pred1
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy1=accuracy_score(y_test,y_pred1)
accuracy1
# Out:
# 0.945291915129663

# %%
from sklearn.metrics import confusion_matrix
conf_mat = confusion_matrix(y_test,y_pred)
conf_mat
# Out:
# array([[26148,   242],
#        [  916,  1538]])

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# ***CLASSIFICATION REPORT FOR LOGISTIC***

# %%
target_names=["no diabetes","diabetes"]         
class_report_logistic = classification_report(y_test,y_pred,target_names=target_names)
print(class_report_logistic)
# Out:
#               precision    recall  f1-score   support
#
#  no diabetes       0.97      0.99      0.98     26390
#     diabetes       0.86      0.63      0.73      2454
#
#     accuracy                           0.96     28844
#    macro avg       0.92      0.81      0.85     28844
# weighted avg       0.96      0.96      0.96     28844

# %%
PRECISION FOR THIS MODEL IS 95% WHICH MEANS 5% OF THE PEOPLE PREDICT TO HAVE DIABETES,DO NOT HAVE IT.RECALL OF THE MODEL IS 96% AN 45 OF THE PEOPLE DO NOT HAVE DIABETES BUT MODEL SAID THEY HAVE.

# %% [markdown]
# **CLASSIFICATION REPORT FOR SDG**

# %%
target_names=["no diabetes","diabetes"]
class_report_SDG = classification_report(y_test,y_pred1,target_names=target_names)
print(class_report_SDG)
# Out:
#               precision    recall  f1-score   support
#
#  no diabetes       0.97      0.97      0.97     26390
#     diabetes       0.66      0.72      0.69      2454
#
#     accuracy                           0.95     28844
#    macro avg       0.82      0.85      0.83     28844
# weighted avg       0.95      0.95      0.95     28844
